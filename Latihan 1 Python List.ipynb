# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
A = [5,10,6,0,4]

# %%
B = A

# %%
B
# Out:
# [5, 10, 6, 0, 4]

# %%
A.reverse()

# %%
A
# Out:
# [4, 0, 6, 10, 5]

# %%
B
# Out:
# [4, 0, 6, 10, 5]

# %%
print('A yang sudah dibalik, ', A)
# Out:
# A yang sudah dibalik,  [4, 0, 6, 10, 5]

# %% [markdown]
# Menampilkan bilangan genap saja dan tidak terbalik.

# %%
x = []
for i in A:
    if i%2 == 0 and i > 0:
        x.append(i)
    else:
        x.append('')
x.reverse()
b = x
b
# Out:
# ['', 10, 6, '', 4]

# %%
A = ['kukuh','pradipto','alvi','alviani','jeje']

# %%
y = []
for i in A:
    print(i)
# Out:
# kukuh
# pradipto
# alvi
# alviani
# jeje

# %%
y = []
for i in A:
    if len(i) > 4:
        y.append(i)
    else:
        y.append('tidak memenuhi syarat')
b = y
b
# Out:
# ['kukuh',
#  'pradipto',
#  'tidak memenuhi syarat',
#  'alviani',
#  'tidak memenuhi syarat']

# %%
 nama = input()
# Out:
# Kukuh

# %%
usia = input()
# Out:
# 23

# %%
tahun = (2022 - 23) + 100

# %%
print('Hallo {a} saat ini usia kamu {b} dan pada tahun {c} usia kamu akan 100 tahun'.format(a=nama, b = usia, c = tahun))
# Out:
# Hallo Kukuh saat ini usia kamu 23 dan pada tahun 2099 usia kamu akan 100 tahun
